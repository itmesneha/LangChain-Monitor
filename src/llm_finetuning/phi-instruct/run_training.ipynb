# %%
import torch
from data import form_dataset
from trainer import get_trainer

# %%
form_dataset(
    dataset_path="raw_data.json",
    train_output_path="chat_finetune_train.json",
    val_output_path="chat_finetune_val.json",
    val_ratio=0.1,
)

# %%
trainer = get_trainer()
trainer.train()
